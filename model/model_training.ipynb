# %%
import pandas as pd 
import optuna
import os 
import joblib
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error

# %%
def objective(trial, X_train, X_test, y_train, y_test):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 50, 500, step=50),
        "max_depth": trial.suggest_int("max_depth", 3, 50),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 20),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 10),
        "max_features": trial.suggest_categorical("max_features", ["sqrt", "log2", None]),
        "bootstrap": trial.suggest_categorical("bootstrap", [True, False]),
        "min_weight_fraction_leaf": trial.suggest_float("min_weight_fraction_leaf", 0.0, 0.5),
        "max_samples": trial.suggest_float("max_samples", 0.5, 1.0) if trial.suggest_categorical("bootstrap", [True, False]) else None,
        "criterion": trial.suggest_categorical("criterion", ["squared_error", "absolute_error"]),
    }

    model = RandomForestRegressor(**params, random_state=42)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    return mean_squared_error(y_test, y_pred)

# %%
leagues = ["cl", "bundesliga", "eredivise","seriea", "ligue1", "laliga", "premier_league"]

model_dir = "models"
os.makedirs(model_dir, exist_ok=True)

for league in leagues:
    print(f"Training model for {league}")

    file_path = f"../train_data/data/{league}_train.csv"
    if not os.path.exists(file_path):
        print(f"File {file_path} does not exist")
        continue

    df = pd.read_csv(file_path)

    label_encoder = LabelEncoder()
    df["Home Team"] = label_encoder.fit_transform(df["Home Team"])
    df["Away Team"] = label_encoder.fit_transform(df["Away Team"])


    X = df.drop(columns=["Home Score", "Away Score"])
    y_home = df["Home Score"]
    y_away = df["Away Score"]

    X_train, X_test, y_train_home, y_test_home = train_test_split(X, y_home, test_size=0.2, random_state=42)
    X_train, X_test, y_train_away, y_test_away = train_test_split(X, y_away, test_size=0.2, random_state=42)

    study_home = optuna.create_study(direction="minimize")
    study_home.optimize(lambda trial: objective(trial, X_train, X_test, y_train_home, y_test_home), n_trials=20)

    study_away = optuna.create_study(direction="minimize")
    study_away.optimize(lambda trial: objective(trial, X_train, X_test, y_train_away, y_test_away), n_trials=20)

    best_params_home = study_home.best_params
    best_params_away = study_away.best_params

    model_home = RandomForestRegressor(**best_params_home, random_state=42)
    model_away = RandomForestRegressor(**best_params_away, random_state=42)

    model_home.fit(X_train, y_train_home)
    model_away.fit(X_train, y_train_away)
    
    y_pred_home = model_home.predict(X_test)
    y_pred_away = model_away.predict(X_test)

    mae_home = mean_squared_error(y_test_home, y_pred_home)
    mae_away = mean_squared_error(y_test_away, y_pred_away)

    print(f"MSE (Home): {mae_home:.2f}, MSE (Away): {mae_away:.2f}")

    joblib.dump(model_home, f"{model_dir}/{league}_home.pkl")
    joblib.dump(model_away, f"{model_dir}/{league}_away.pkl")

    print(f"Model Saved: {league}")

print("Training Completed")
# Out:
# [I 2025-02-27 22:08:01,857] A new study created in memory with name: no-name-084bae58-42ec-40f5-9fbe-9ebc71c7af2b
# [I 2025-02-27 22:08:01,966] Trial 0 finished with value: 2.2887303824725893 and parameters: {'n_estimators': 100, 'max_depth': 33, 'min_samples_split': 17, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.14456529363845116, 'max_samples': 0.820005572091375, 'criterion': 'squared_error'}. Best is trial 0 with value: 2.2887303824725893.
# Training model for cl
# [I 2025-02-27 22:08:02,267] Trial 1 finished with value: 2.2063461409729657 and parameters: {'n_estimators': 450, 'max_depth': 30, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': False, 'min_weight_fraction_leaf': 0.030077850072427248, 'criterion': 'squared_error'}. Best is trial 1 with value: 2.2063461409729657.
# [I 2025-02-27 22:08:02,333] Trial 2 finished with value: 1.9290516532911184 and parameters: {'n_estimators': 50, 'max_depth': 32, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': False, 'min_weight_fraction_leaf': 0.013484379183916262, 'criterion': 'squared_error'}. Best is trial 2 with value: 1.9290516532911184.
# [I 2025-02-27 22:08:02,854] Trial 3 finished with value: 2.15625 and parameters: {'n_estimators': 250, 'max_depth': 47, 'min_samples_split': 5, 'min_samples_leaf': 8, 'max_features': None, 'bootstrap': False, 'min_weight_fraction_leaf': 0.42130940733255706, 'criterion': 'absolute_error'}. Best is trial 2 with value: 1.9290516532911184.
# [I 2025-02-27 22:08:03,030] Trial 4 finished with value: 2.6204071044921875 and parameters: {'n_estimators': 250, 'max_depth': 13, 'min_samples_split': 18, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': False, 'min_weight_fraction_leaf': 0.37374924910453555, 'criterion': 'squared_error'}. Best is trial 2 with value: 1.9290516532911184.
# [I 2025-02-27 22:08:03,230] Trial 5 finished with value: 2.2212642936733964 and parameters: {'n_estimators': 350, 'max_depth': 27, 'min_samples_split': 8, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': False, 'min_weight_fraction_leaf': 0.11151244131220261, 'criterion': 'squared_error'}. Best is trial 2 with value: 1.9290516532911184.
# [I 2025-02-27 22:08:03,355] Trial 6 finished with value: 2.3462700440967685 and parameters: {'n_estimators': 150, 'max_depth': 23, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': 'log2', 'bootstrap': True, 'min_weight_fraction_leaf': 0.41137747467313274, 'max_samples': 0.6367298506399726, 'criterion': 'squared_error'}. Best is trial 2 with value: 1.9290516532911184.
# [I 2025-02-27 22:08:03,593] Trial 7 finished with value: 2.348710899893025 and parameters: {'n_estimators': 450, 'max_depth': 36, 'min_samples_split': 17, 'min_samples_leaf': 10, 'max_features': 'log2', 'bootstrap': False, 'min_weight_fraction_leaf': 0.38479979412422144, 'criterion': 'squared_error'}. Best is trial 2 with value: 1.9290516532911184.
# [I 2025-02-27 22:08:03,746] Trial 8 finished with value: 2.1289534722222223 and parameters: {'n_estimators': 150, 'max_depth': 29, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.020572348004453067, 'max_samples': 0.5117081778049315, 'criterion': 'absolute_error'}. Best is trial 2 with value: 1.9290516532911184.
# [I 2025-02-27 22:08:04,034] Trial 9 finished with value: 2.228390857718745 and parameters: {'n_estimators': 350, 'max_depth': 27, 'min_samples_split': 6, 'min_samples_leaf': 6, 'max_features': 'log2', 'bootstrap': True, 'min_weight_fraction_leaf': 0.050752259721607795, 'max_samples': 0.6661754883562964, 'criterion': 'squared_error'}. Best is trial 2 with value: 1.9290516532911184.
# [I 2025-02-27 22:08:04,210] Trial 10 finished with value: 1.917825 and parameters: {'n_estimators': 50, 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': False, 'min_weight_fraction_leaf': 0.23811244293419748, 'criterion': 'absolute_error'}. Best is trial 10 with value: 1.917825.
# [I 2025-02-27 22:08:04,384] Trial 11 finished with value: 1.917825 and parameters: {'n_estimators': 50, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': False, 'min_weight_fraction_leaf': 0.2693985482213571, 'criterion': 'absolute_error'}. Best is trial 10 with value: 1.917825.
# [I 2025-02-27 22:08:04,560] Trial 12 finished with value: 1.917825 and parameters: {'n_estimators': 50, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': False, 'min_weight_fraction_leaf': 0.2506398946705089, 'criterion': 'absolute_error'}. Best is trial 10 with value: 1.917825.
# [I 2025-02-27 22:08:05,074] Trial 13 finished with value: 1.9238 and parameters: {'n_estimators': 150, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': False, 'min_weight_fraction_leaf': 0.2526220480772634, 'criterion': 'absolute_error'}. Best is trial 10 with value: 1.917825.
# [I 2025-02-27 22:08:05,253] Trial 14 finished with value: 2.21875 and parameters: {'n_estimators': 50, 'max_depth': 12, 'min_samples_split': 14, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': False, 'min_weight_fraction_leaf': 0.31021432763694723, 'criterion': 'absolute_error'}. Best is trial 10 with value: 1.917825.
# [I 2025-02-27 22:08:05,703] Trial 15 finished with value: 2.4024 and parameters: {'n_estimators': 200, 'max_depth': 12, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': False, 'min_weight_fraction_leaf': 0.4969485323434456, 'criterion': 'absolute_error'}. Best is trial 10 with value: 1.917825.
# [I 2025-02-27 22:08:06,138] Trial 16 finished with value: 2.3125 and parameters: {'n_estimators': 100, 'max_depth': 18, 'min_samples_split': 12, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': False, 'min_weight_fraction_leaf': 0.17598360174049513, 'criterion': 'absolute_error'}. Best is trial 10 with value: 1.917825.
# [I 2025-02-27 22:08:07,575] Trial 17 finished with value: 2.3125 and parameters: {'n_estimators': 350, 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': False, 'min_weight_fraction_leaf': 0.19667198748185422, 'criterion': 'absolute_error'}. Best is trial 10 with value: 1.917825.
# [I 2025-02-27 22:08:07,805] Trial 18 finished with value: 2.0028890625 and parameters: {'n_estimators': 100, 'max_depth': 19, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.3137742859151724, 'max_samples': 0.9671793848729993, 'criterion': 'absolute_error'}. Best is trial 10 with value: 1.917825.
# [I 2025-02-27 22:08:07,996] Trial 19 finished with value: 2.0573078125000004 and parameters: {'n_estimators': 200, 'max_depth': 7, 'min_samples_split': 20, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': False, 'min_weight_fraction_leaf': 0.2972349530615366, 'criterion': 'absolute_error'}. Best is trial 10 with value: 1.917825.
# [I 2025-02-27 22:08:07,997] A new study created in memory with name: no-name-c74971b8-00ab-4829-b347-43375c2de469
# [I 2025-02-27 22:08:08,138] Trial 0 finished with value: 2.3921785386853553 and parameters: {'n_estimators': 200, 'max_depth': 34, 'min_samples_split': 13, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': False, 'min_weight_fraction_leaf': 0.4720206837469514, 'criterion': 'squared_error'}. Best is trial 0 with value: 2.3921785386853553.
# [I 2025-02-27 22:08:08,170] Trial 1 finished with value: 2.280965358450775 and parameters: {'n_estimators': 50, 'max_depth': 39, 'min_samples_split': 20, 'min_samples_leaf': 9, 'max_features': 'log2', 'bootstrap': False, 'min_weight_fraction_leaf': 0.4309293428578733, 'criterion': 'squared_error'}. Best is trial 1 with value: 2.280965358450775.
# [I 2025-02-27 22:08:08,445] Trial 2 finished with value: 2.2513140624999997 and parameters: {'n_estimators': 200, 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 10, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.35468988857716793, 'max_samples': 0.5878633150925467, 'criterion': 'absolute_error'}. Best is trial 2 with value: 2.2513140624999997.
# [I 2025-02-27 22:08:08,726] Trial 3 finished with value: 1.8582977430555556 and parameters: {'n_estimators': 300, 'max_depth': 44, 'min_samples_split': 19, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': True, 'min_weight_fraction_leaf': 0.12309707436093081, 'max_samples': 0.5171394975714307, 'criterion': 'absolute_error'}. Best is trial 3 with value: 1.8582977430555556.
# [I 2025-02-27 22:08:09,204] Trial 4 finished with value: 1.6957537181531603 and parameters: {'n_estimators': 350, 'max_depth': 25, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.05197781800767398, 'max_samples': 0.8552745311991302, 'criterion': 'squared_error'}. Best is trial 4 with value: 1.6957537181531603.
# [I 2025-02-27 22:08:09,454] Trial 5 finished with value: 1.9230594735582334 and parameters: {'n_estimators': 250, 'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.24271860950432567, 'max_samples': 0.7011816956603897, 'criterion': 'squared_error'}. Best is trial 4 with value: 1.6957537181531603.
# [I 2025-02-27 22:08:09,697] Trial 6 finished with value: 2.2178134463502595 and parameters: {'n_estimators': 300, 'max_depth': 14, 'min_samples_split': 16, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.4045825184912676, 'max_samples': 0.8365993274723424, 'criterion': 'squared_error'}. Best is trial 4 with value: 1.6957537181531603.
# [I 2025-02-27 22:08:09,807] Trial 7 finished with value: 2.53125 and parameters: {'n_estimators': 50, 'max_depth': 29, 'min_samples_split': 16, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': False, 'min_weight_fraction_leaf': 0.3841664855813001, 'criterion': 'absolute_error'}. Best is trial 4 with value: 1.6957537181531603.
# [I 2025-02-27 22:08:10,341] Trial 8 finished with value: 1.7660851540752698 and parameters: {'n_estimators': 500, 'max_depth': 8, 'min_samples_split': 16, 'min_samples_leaf': 9, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.15477974809451572, 'max_samples': 0.7523395339509951, 'criterion': 'squared_error'}. Best is trial 4 with value: 1.6957537181531603.
# [I 2025-02-27 22:08:10,763] Trial 9 finished with value: 2.90625 and parameters: {'n_estimators': 200, 'max_depth': 39, 'min_samples_split': 11, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': False, 'min_weight_fraction_leaf': 0.4807255704317304, 'criterion': 'absolute_error'}. Best is trial 4 with value: 1.6957537181531603.
# [I 2025-02-27 22:08:11,207] Trial 10 finished with value: 1.6726465034293552 and parameters: {'n_estimators': 450, 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.008186653458983825, 'max_samples': 0.9042757337241051, 'criterion': 'squared_error'}. Best is trial 10 with value: 1.6726465034293552.
# [I 2025-02-27 22:08:11,658] Trial 11 finished with value: 1.6733488192729766 and parameters: {'n_estimators': 450, 'max_depth': 19, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.006180561684134576, 'max_samples': 0.9897727240356141, 'criterion': 'squared_error'}. Best is trial 10 with value: 1.6726465034293552.
# [I 2025-02-27 22:08:12,151] Trial 12 finished with value: 1.6233502255761052 and parameters: {'n_estimators': 500, 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.009456679188041144, 'max_samples': 0.9957218451714704, 'criterion': 'squared_error'}. Best is trial 12 with value: 1.6233502255761052.
# [I 2025-02-27 22:08:12,510] Trial 13 finished with value: 1.7206560152542756 and parameters: {'n_estimators': 400, 'max_depth': 20, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.09412224772469564, 'max_samples': 0.987996757913967, 'criterion': 'squared_error'}. Best is trial 12 with value: 1.6233502255761052.
# [I 2025-02-27 22:08:12,941] Trial 14 finished with value: 1.9320544391043177 and parameters: {'n_estimators': 500, 'max_depth': 19, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.20849667823535, 'max_samples': 0.9127983946445581, 'criterion': 'squared_error'}. Best is trial 12 with value: 1.6233502255761052.
# [I 2025-02-27 22:08:13,301] Trial 15 finished with value: 1.6845394627024541 and parameters: {'n_estimators': 400, 'max_depth': 26, 'min_samples_split': 9, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.02441347715591846, 'max_samples': 0.9076351773875733, 'criterion': 'squared_error'}. Best is trial 12 with value: 1.6233502255761052.
# [I 2025-02-27 22:08:13,682] Trial 16 finished with value: 2.187901558706236 and parameters: {'n_estimators': 450, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.3238362187373339, 'max_samples': 0.9934299873813995, 'criterion': 'squared_error'}. Best is trial 12 with value: 1.6233502255761052.
# [I 2025-02-27 22:08:14,113] Trial 17 finished with value: 1.8350376719251986 and parameters: {'n_estimators': 500, 'max_depth': 13, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.17171021658587723, 'max_samples': 0.7695836870083126, 'criterion': 'squared_error'}. Best is trial 12 with value: 1.6233502255761052.
# [I 2025-02-27 22:08:14,681] Trial 18 finished with value: 1.69874638671875 and parameters: {'n_estimators': 400, 'max_depth': 30, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': False, 'min_weight_fraction_leaf': 0.07467974673135376, 'criterion': 'absolute_error'}. Best is trial 12 with value: 1.6233502255761052.
# [I 2025-02-27 22:08:15,067] Trial 19 finished with value: 2.085041426497569 and parameters: {'n_estimators': 450, 'max_depth': 22, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': True, 'min_weight_fraction_leaf': 0.27998817570374857, 'max_samples': 0.9113315743388115, 'criterion': 'squared_error'}. Best is trial 12 with value: 1.6233502255761052.
# [I 2025-02-27 22:08:15,819] A new study created in memory with name: no-name-dccf774f-f065-443a-ab60-9c786784cddf
# MSE (Home): 1.92, MSE (Away): 1.62
# Model Saved: cl
# Training model for bundesliga
# [I 2025-02-27 22:08:16,232] Trial 0 finished with value: 1.4555665407897314 and parameters: {'n_estimators': 500, 'max_depth': 11, 'min_samples_split': 11, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.3388091654666965, 'max_samples': 0.7330184998658967, 'criterion': 'squared_error'}. Best is trial 0 with value: 1.4555665407897314.
# [I 2025-02-27 22:08:16,366] Trial 1 finished with value: 1.6002730158730158 and parameters: {'n_estimators': 150, 'max_depth': 12, 'min_samples_split': 17, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': False, 'min_weight_fraction_leaf': 0.3828198856143009, 'criterion': 'absolute_error'}. Best is trial 0 with value: 1.4555665407897314.
# [I 2025-02-27 22:08:16,607] Trial 2 finished with value: 1.5776246666666665 and parameters: {'n_estimators': 250, 'max_depth': 22, 'min_samples_split': 14, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True, 'min_weight_fraction_leaf': 0.26825841719314786, 'max_samples': 0.6196130776110098, 'criterion': 'absolute_error'}. Best is trial 0 with value: 1.4555665407897314.
# [I 2025-02-27 22:08:16,988] Trial 3 finished with value: 1.8075192745672566 and parameters: {'n_estimators': 350, 'max_depth': 30, 'min_samples_split': 4, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': False, 'min_weight_fraction_leaf': 0.09192308579448771, 'criterion': 'squared_error'}. Best is trial 0 with value: 1.4555665407897314.
# [I 2025-02-27 22:08:17,367] Trial 4 finished with value: 1.692442738598323 and parameters: {'n_estimators': 400, 'max_depth': 24, 'min_samples_split': 14, 'min_samples_leaf': 6, 'max_features': None, 'bootstrap': False, 'min_weight_fraction_leaf': 0.16969480009219884, 'criterion': 'squared_error'}. Best is trial 0 with value: 1.4555665407897314.
# [I 2025-02-27 22:08:17,875] Trial 5 finished with value: 1.574365138154027 and parameters: {'n_estimators': 450, 'max_depth': 40, 'min_samples_split': 20, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True, 'min_weight_fraction_leaf': 0.06810224387508623, 'max_samples': 0.7177541692024554, 'criterion': 'absolute_error'}. Best is trial 0 with value: 1.4555665407897314.
# [I 2025-02-27 22:08:19,203] Trial 6 finished with value: 1.8672177083333332 and parameters: {'n_estimators': 200, 'max_depth': 14, 'min_samples_split': 15, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': False, 'min_weight_fraction_leaf': 0.07987908412302103, 'criterion': 'absolute_error'}. Best is trial 0 with value: 1.4555665407897314.
# [I 2025-02-27 22:08:20,455] Trial 7 finished with value: 1.6760326278659614 and parameters: {'n_estimators': 450, 'max_depth': 44, 'min_samples_split': 18, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.18584536060036788, 'max_samples': 0.7838101065814769, 'criterion': 'absolute_error'}. Best is trial 0 with value: 1.4555665407897314.
# [I 2025-02-27 22:08:20,843] Trial 8 finished with value: 1.5971390476190477 and parameters: {'n_estimators': 250, 'max_depth': 29, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.0426501888080435, 'max_samples': 0.9654232240813094, 'criterion': 'absolute_error'}. Best is trial 0 with value: 1.4555665407897314.
# [I 2025-02-27 22:08:21,020] Trial 9 finished with value: 1.5463010808783597 and parameters: {'n_estimators': 300, 'max_depth': 16, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': False, 'min_weight_fraction_leaf': 0.13708525909093938, 'criterion': 'squared_error'}. Best is trial 0 with value: 1.4555665407897314.
# [I 2025-02-27 22:08:21,435] Trial 10 finished with value: 1.7271377299983524 and parameters: {'n_estimators': 500, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.49677497476671056, 'max_samples': 0.5161931878440061, 'criterion': 'squared_error'}. Best is trial 0 with value: 1.4555665407897314.
# [I 2025-02-27 22:08:21,486] Trial 11 finished with value: 1.490322243329224 and parameters: {'n_estimators': 50, 'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': False, 'min_weight_fraction_leaf': 0.31923287846370796, 'criterion': 'squared_error'}. Best is trial 0 with value: 1.4555665407897314.
# [I 2025-02-27 22:08:21,535] Trial 12 finished with value: 1.4918790170957403 and parameters: {'n_estimators': 50, 'max_depth': 4, 'min_samples_split': 8, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': False, 'min_weight_fraction_leaf': 0.32239919271121903, 'criterion': 'squared_error'}. Best is trial 0 with value: 1.4555665407897314.
# [I 2025-02-27 22:08:21,602] Trial 13 finished with value: 1.4944700576801093 and parameters: {'n_estimators': 50, 'max_depth': 3, 'min_samples_split': 11, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.4014947036681756, 'max_samples': 0.8791578075626733, 'criterion': 'squared_error'}. Best is trial 0 with value: 1.4555665407897314.
# [I 2025-02-27 22:08:21,708] Trial 14 finished with value: 1.4648127950749312 and parameters: {'n_estimators': 150, 'max_depth': 9, 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'bootstrap': False, 'min_weight_fraction_leaf': 0.285323015485489, 'criterion': 'squared_error'}. Best is trial 0 with value: 1.4555665407897314.
# [I 2025-02-27 22:08:21,856] Trial 15 finished with value: 1.4737455611787111 and parameters: {'n_estimators': 150, 'max_depth': 19, 'min_samples_split': 2, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.24082471045169873, 'max_samples': 0.740198175754248, 'criterion': 'squared_error'}. Best is trial 0 with value: 1.4555665407897314.
# [I 2025-02-27 22:08:21,998] Trial 16 finished with value: 1.492877516205434 and parameters: {'n_estimators': 150, 'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 5, 'max_features': 'log2', 'bootstrap': True, 'min_weight_fraction_leaf': 0.4374354776030572, 'max_samples': 0.62708237938301, 'criterion': 'squared_error'}. Best is trial 0 with value: 1.4555665407897314.
# [I 2025-02-27 22:08:22,219] Trial 17 finished with value: 1.4527736223566083 and parameters: {'n_estimators': 350, 'max_depth': 32, 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'bootstrap': False, 'min_weight_fraction_leaf': 0.27702719331095527, 'criterion': 'squared_error'}. Best is trial 17 with value: 1.4527736223566083.
# [I 2025-02-27 22:08:22,519] Trial 18 finished with value: 1.5116886050076914 and parameters: {'n_estimators': 500, 'max_depth': 34, 'min_samples_split': 12, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': False, 'min_weight_fraction_leaf': 0.23312045355175526, 'criterion': 'squared_error'}. Best is trial 17 with value: 1.4527736223566083.
# [I 2025-02-27 22:08:22,817] Trial 19 finished with value: 1.472247465783615 and parameters: {'n_estimators': 350, 'max_depth': 49, 'min_samples_split': 12, 'min_samples_leaf': 7, 'max_features': 'log2', 'bootstrap': True, 'min_weight_fraction_leaf': 0.36142458553275153, 'max_samples': 0.8572119697512246, 'criterion': 'squared_error'}. Best is trial 17 with value: 1.4527736223566083.
# [I 2025-02-27 22:08:22,818] A new study created in memory with name: no-name-62f36da8-6d82-4628-925d-a58fd997cf8d
# [I 2025-02-27 22:08:23,130] Trial 0 finished with value: 1.47161986852433 and parameters: {'n_estimators': 350, 'max_depth': 46, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.47259267998902665, 'max_samples': 0.7034960634908176, 'criterion': 'squared_error'}. Best is trial 0 with value: 1.47161986852433.
# [I 2025-02-27 22:08:23,176] Trial 1 finished with value: 1.4499715816587666 and parameters: {'n_estimators': 50, 'max_depth': 16, 'min_samples_split': 20, 'min_samples_leaf': 3, 'max_features': 'log2', 'bootstrap': True, 'min_weight_fraction_leaf': 0.1491835299279532, 'max_samples': 0.8318406696642102, 'criterion': 'squared_error'}. Best is trial 1 with value: 1.4499715816587666.
# [I 2025-02-27 22:08:23,814] Trial 2 finished with value: 1.3807166666666664 and parameters: {'n_estimators': 250, 'max_depth': 17, 'min_samples_split': 20, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.26547049137286527, 'max_samples': 0.8419501449137667, 'criterion': 'absolute_error'}. Best is trial 2 with value: 1.3807166666666664.
# [I 2025-02-27 22:08:24,112] Trial 3 finished with value: 1.4096352275917756 and parameters: {'n_estimators': 250, 'max_depth': 31, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.0005470402301875343, 'max_samples': 0.8735527717430958, 'criterion': 'squared_error'}. Best is trial 2 with value: 1.3807166666666664.
# [I 2025-02-27 22:08:24,159] Trial 4 finished with value: 1.4520166881860341 and parameters: {'n_estimators': 50, 'max_depth': 34, 'min_samples_split': 18, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.15713566899301662, 'max_samples': 0.8122083393835751, 'criterion': 'squared_error'}. Best is trial 2 with value: 1.3807166666666664.
# [I 2025-02-27 22:08:24,460] Trial 5 finished with value: 1.3892599617717687 and parameters: {'n_estimators': 350, 'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.09932848387152304, 'max_samples': 0.639618883758015, 'criterion': 'squared_error'}. Best is trial 2 with value: 1.3807166666666664.
# [I 2025-02-27 22:08:24,790] Trial 6 finished with value: 1.4195636572934998 and parameters: {'n_estimators': 350, 'max_depth': 8, 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.2769006537627154, 'max_samples': 0.5176124363851874, 'criterion': 'squared_error'}. Best is trial 2 with value: 1.3807166666666664.
# [I 2025-02-27 22:08:25,271] Trial 7 finished with value: 1.4343154160523806 and parameters: {'n_estimators': 500, 'max_depth': 39, 'min_samples_split': 16, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.29145667806608444, 'max_samples': 0.874094714611749, 'criterion': 'squared_error'}. Best is trial 2 with value: 1.3807166666666664.
# [I 2025-02-27 22:08:25,446] Trial 8 finished with value: 1.4079829650184763 and parameters: {'n_estimators': 150, 'max_depth': 38, 'min_samples_split': 3, 'min_samples_leaf': 9, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.0806355702613692, 'max_samples': 0.7151253433756126, 'criterion': 'squared_error'}. Best is trial 2 with value: 1.3807166666666664.
# [I 2025-02-27 22:08:27,512] Trial 9 finished with value: 1.5456180059523807 and parameters: {'n_estimators': 400, 'max_depth': 22, 'min_samples_split': 7, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False, 'min_weight_fraction_leaf': 0.15771783760595337, 'criterion': 'absolute_error'}. Best is trial 2 with value: 1.3807166666666664.
# [I 2025-02-27 22:08:27,690] Trial 10 finished with value: 1.5296946428571427 and parameters: {'n_estimators': 200, 'max_depth': 22, 'min_samples_split': 14, 'min_samples_leaf': 6, 'max_features': 'log2', 'bootstrap': False, 'min_weight_fraction_leaf': 0.41368802654548187, 'criterion': 'absolute_error'}. Best is trial 2 with value: 1.3807166666666664.
# [I 2025-02-27 22:08:27,969] Trial 11 finished with value: 1.4017010582010583 and parameters: {'n_estimators': 300, 'max_depth': 3, 'min_samples_split': 13, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': False, 'min_weight_fraction_leaf': 0.3626948071634164, 'criterion': 'absolute_error'}. Best is trial 2 with value: 1.3807166666666664.
# [I 2025-02-27 22:08:28,445] Trial 12 finished with value: 1.4011736625514404 and parameters: {'n_estimators': 450, 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.2226333879079903, 'max_samples': 0.6035053363690814, 'criterion': 'absolute_error'}. Best is trial 2 with value: 1.3807166666666664.
# [I 2025-02-27 22:08:28,741] Trial 13 finished with value: 1.3595050264550264 and parameters: {'n_estimators': 150, 'max_depth': 15, 'min_samples_split': 11, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.006323857866277982, 'max_samples': 0.9509004171349069, 'criterion': 'absolute_error'}. Best is trial 13 with value: 1.3595050264550264.
# [I 2025-02-27 22:08:28,892] Trial 14 finished with value: 1.3993735449735447 and parameters: {'n_estimators': 150, 'max_depth': 18, 'min_samples_split': 12, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': False, 'min_weight_fraction_leaf': 0.3408517917044987, 'criterion': 'absolute_error'}. Best is trial 13 with value: 1.3595050264550264.
# [I 2025-02-27 22:08:29,123] Trial 15 finished with value: 1.4618083333333334 and parameters: {'n_estimators': 200, 'max_depth': 14, 'min_samples_split': 16, 'min_samples_leaf': 7, 'max_features': 'log2', 'bootstrap': True, 'min_weight_fraction_leaf': 0.22763535374951052, 'max_samples': 0.99774215409304, 'criterion': 'absolute_error'}. Best is trial 13 with value: 1.3595050264550264.
# [I 2025-02-27 22:08:29,248] Trial 16 finished with value: 1.4601666666666666 and parameters: {'n_estimators': 100, 'max_depth': 24, 'min_samples_split': 11, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.33203845866713455, 'max_samples': 0.9902279213521668, 'criterion': 'absolute_error'}. Best is trial 13 with value: 1.3595050264550264.
# [I 2025-02-27 22:08:29,647] Trial 17 finished with value: 1.344926095238095 and parameters: {'n_estimators': 250, 'max_depth': 28, 'min_samples_split': 20, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.018318023937964393, 'max_samples': 0.9279786349404648, 'criterion': 'absolute_error'}. Best is trial 17 with value: 1.344926095238095.
# [I 2025-02-27 22:08:29,977] Trial 18 finished with value: 1.4168037037037038 and parameters: {'n_estimators': 150, 'max_depth': 28, 'min_samples_split': 15, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': False, 'min_weight_fraction_leaf': 0.0031690567441724866, 'criterion': 'absolute_error'}. Best is trial 17 with value: 1.344926095238095.
# [I 2025-02-27 22:08:30,265] Trial 19 finished with value: 1.3645815476190477 and parameters: {'n_estimators': 200, 'max_depth': 50, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.05928693218506549, 'max_samples': 0.9306348394768362, 'criterion': 'absolute_error'}. Best is trial 17 with value: 1.344926095238095.
# [I 2025-02-27 22:08:30,964] A new study created in memory with name: no-name-517392b9-d910-4e33-b746-bb02dd0111da
# MSE (Home): 1.45, MSE (Away): 1.34
# Model Saved: bundesliga
# Training model for eredivise
# [I 2025-02-27 22:08:31,105] Trial 0 finished with value: 1.6044158765946943 and parameters: {'n_estimators': 150, 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.4954956408736817, 'max_samples': 0.6430720111730451, 'criterion': 'squared_error'}. Best is trial 0 with value: 1.6044158765946943.
# [I 2025-02-27 22:08:31,422] Trial 1 finished with value: 1.5197244968650863 and parameters: {'n_estimators': 400, 'max_depth': 32, 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.42578264892717504, 'max_samples': 0.5238742784515402, 'criterion': 'squared_error'}. Best is trial 1 with value: 1.5197244968650863.
# [I 2025-02-27 22:08:31,599] Trial 2 finished with value: 1.5343883597883596 and parameters: {'n_estimators': 150, 'max_depth': 10, 'min_samples_split': 15, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': False, 'min_weight_fraction_leaf': 0.17841075162436326, 'criterion': 'absolute_error'}. Best is trial 1 with value: 1.5197244968650863.
# [I 2025-02-27 22:08:31,741] Trial 3 finished with value: 1.7193619047619026 and parameters: {'n_estimators': 200, 'max_depth': 36, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': False, 'min_weight_fraction_leaf': 0.36278819495451414, 'criterion': 'squared_error'}. Best is trial 1 with value: 1.5197244968650863.
# [I 2025-02-27 22:08:32,066] Trial 4 finished with value: 1.4275907665817964 and parameters: {'n_estimators': 400, 'max_depth': 4, 'min_samples_split': 19, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': True, 'min_weight_fraction_leaf': 0.18412132494716338, 'max_samples': 0.7772378038610389, 'criterion': 'squared_error'}. Best is trial 4 with value: 1.4275907665817964.
# [I 2025-02-27 22:08:32,467] Trial 5 finished with value: 1.5325666666666664 and parameters: {'n_estimators': 350, 'max_depth': 36, 'min_samples_split': 20, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'bootstrap': False, 'min_weight_fraction_leaf': 0.1689972369406484, 'criterion': 'absolute_error'}. Best is trial 4 with value: 1.4275907665817964.
# [I 2025-02-27 22:08:32,724] Trial 6 finished with value: 1.5002661375661375 and parameters: {'n_estimators': 300, 'max_depth': 48, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': False, 'min_weight_fraction_leaf': 0.4535686907948588, 'criterion': 'absolute_error'}. Best is trial 4 with value: 1.4275907665817964.
# [I 2025-02-27 22:08:33,137] Trial 7 finished with value: 1.4334800774733902 and parameters: {'n_estimators': 500, 'max_depth': 20, 'min_samples_split': 9, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.17651177592298917, 'max_samples': 0.9458882135088348, 'criterion': 'squared_error'}. Best is trial 4 with value: 1.4275907665817964.
# [I 2025-02-27 22:08:33,234] Trial 8 finished with value: 1.5690559523809524 and parameters: {'n_estimators': 100, 'max_depth': 29, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': 'log2', 'bootstrap': False, 'min_weight_fraction_leaf': 0.21401481850483545, 'criterion': 'absolute_error'}. Best is trial 4 with value: 1.4275907665817964.
# [I 2025-02-27 22:08:33,318] Trial 9 finished with value: 1.5496482318318943 and parameters: {'n_estimators': 100, 'max_depth': 46, 'min_samples_split': 15, 'min_samples_leaf': 6, 'max_features': 'log2', 'bootstrap': True, 'min_weight_fraction_leaf': 0.4418360517644394, 'max_samples': 0.6375664250492509, 'criterion': 'squared_error'}. Best is trial 4 with value: 1.4275907665817964.
# [I 2025-02-27 22:08:33,757] Trial 10 finished with value: 1.4842165284857418 and parameters: {'n_estimators': 500, 'max_depth': 17, 'min_samples_split': 20, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True, 'min_weight_fraction_leaf': 0.02104498971245017, 'max_samples': 0.8726716561735679, 'criterion': 'squared_error'}. Best is trial 4 with value: 1.4275907665817964.
# [I 2025-02-27 22:08:34,202] Trial 11 finished with value: 1.4736903027378996 and parameters: {'n_estimators': 500, 'max_depth': 19, 'min_samples_split': 12, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True, 'min_weight_fraction_leaf': 0.0658105842840086, 'max_samples': 0.9873642930609174, 'criterion': 'squared_error'}. Best is trial 4 with value: 1.4275907665817964.
# [I 2025-02-27 22:08:34,552] Trial 12 finished with value: 1.4882234342568557 and parameters: {'n_estimators': 400, 'max_depth': 4, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.30856102395976426, 'max_samples': 0.8518428139734422, 'criterion': 'squared_error'}. Best is trial 4 with value: 1.4275907665817964.
# [I 2025-02-27 22:08:34,954] Trial 13 finished with value: 1.4430494944534513 and parameters: {'n_estimators': 450, 'max_depth': 18, 'min_samples_split': 16, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': True, 'min_weight_fraction_leaf': 0.117895790455946, 'max_samples': 0.9973688937043029, 'criterion': 'squared_error'}. Best is trial 4 with value: 1.4275907665817964.
# [I 2025-02-27 22:08:35,267] Trial 14 finished with value: 1.398779152100922 and parameters: {'n_estimators': 300, 'max_depth': 12, 'min_samples_split': 11, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.27370981626190305, 'max_samples': 0.8019715380762293, 'criterion': 'squared_error'}. Best is trial 14 with value: 1.398779152100922.
# [I 2025-02-27 22:08:35,549] Trial 15 finished with value: 1.3985681093492763 and parameters: {'n_estimators': 250, 'max_depth': 12, 'min_samples_split': 13, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.2831952161432775, 'max_samples': 0.7588535682217421, 'criterion': 'squared_error'}. Best is trial 15 with value: 1.3985681093492763.
# [I 2025-02-27 22:08:35,813] Trial 16 finished with value: 1.403580509568161 and parameters: {'n_estimators': 250, 'max_depth': 12, 'min_samples_split': 12, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.28345318186263163, 'max_samples': 0.730697435554791, 'criterion': 'squared_error'}. Best is trial 15 with value: 1.3985681093492763.
# [I 2025-02-27 22:08:36,062] Trial 17 finished with value: 1.4460965727814625 and parameters: {'n_estimators': 250, 'max_depth': 23, 'min_samples_split': 13, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.34540979852571974, 'max_samples': 0.7481276681340926, 'criterion': 'squared_error'}. Best is trial 15 with value: 1.3985681093492763.
# [I 2025-02-27 22:08:36,766] Trial 18 finished with value: 1.5881864417989418 and parameters: {'n_estimators': 300, 'max_depth': 13, 'min_samples_split': 17, 'min_samples_leaf': 10, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.2589984651237818, 'max_samples': 0.8343328169952401, 'criterion': 'absolute_error'}. Best is trial 15 with value: 1.3985681093492763.
# [I 2025-02-27 22:08:36,836] Trial 19 finished with value: 1.4433705557593388 and parameters: {'n_estimators': 50, 'max_depth': 26, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.3596092556235863, 'max_samples': 0.6760911218351822, 'criterion': 'squared_error'}. Best is trial 15 with value: 1.3985681093492763.
# [I 2025-02-27 22:08:36,837] A new study created in memory with name: no-name-eadb67f0-2ba9-4f87-9606-ade1af2bf08e
# [I 2025-02-27 22:08:37,115] Trial 0 finished with value: 1.2071321428571427 and parameters: {'n_estimators': 100, 'max_depth': 39, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.14084094009448306, 'max_samples': 0.6186294492483544, 'criterion': 'absolute_error'}. Best is trial 0 with value: 1.2071321428571427.
# [I 2025-02-27 22:08:37,270] Trial 1 finished with value: 1.2891313587047823 and parameters: {'n_estimators': 250, 'max_depth': 8, 'min_samples_split': 15, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': False, 'min_weight_fraction_leaf': 0.07660523478615017, 'criterion': 'squared_error'}. Best is trial 0 with value: 1.2071321428571427.
# [I 2025-02-27 22:08:37,302] Trial 2 finished with value: 1.1630280932310646 and parameters: {'n_estimators': 50, 'max_depth': 4, 'min_samples_split': 11, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'bootstrap': False, 'min_weight_fraction_leaf': 0.22855372455905326, 'criterion': 'squared_error'}. Best is trial 2 with value: 1.1630280932310646.
# [I 2025-02-27 22:08:37,517] Trial 3 finished with value: 1.2180911250793465 and parameters: {'n_estimators': 250, 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.09545668261091927, 'max_samples': 0.8699212995840844, 'criterion': 'squared_error'}. Best is trial 2 with value: 1.1630280932310646.
# [I 2025-02-27 22:08:37,813] Trial 4 finished with value: 1.2823793931135679 and parameters: {'n_estimators': 250, 'max_depth': 15, 'min_samples_split': 18, 'min_samples_leaf': 10, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.011749331267949914, 'max_samples': 0.8520127435450562, 'criterion': 'squared_error'}. Best is trial 2 with value: 1.1630280932310646.
# [I 2025-02-27 22:08:37,921] Trial 5 finished with value: 1.1793130577356168 and parameters: {'n_estimators': 150, 'max_depth': 19, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': None, 'bootstrap': False, 'min_weight_fraction_leaf': 0.48220206617171946, 'criterion': 'squared_error'}. Best is trial 2 with value: 1.1630280932310646.
# [I 2025-02-27 22:08:38,187] Trial 6 finished with value: 1.2066980958872582 and parameters: {'n_estimators': 500, 'max_depth': 23, 'min_samples_split': 11, 'min_samples_leaf': 3, 'max_features': 'log2', 'bootstrap': False, 'min_weight_fraction_leaf': 0.46925264537433276, 'criterion': 'squared_error'}. Best is trial 2 with value: 1.1630280932310646.
# [I 2025-02-27 22:08:38,335] Trial 7 finished with value: 1.153445238095238 and parameters: {'n_estimators': 50, 'max_depth': 13, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.1351564910362279, 'max_samples': 0.7671901943159665, 'criterion': 'absolute_error'}. Best is trial 7 with value: 1.153445238095238.
# [I 2025-02-27 22:08:38,836] Trial 8 finished with value: 1.215428857142857 and parameters: {'n_estimators': 500, 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'bootstrap': False, 'min_weight_fraction_leaf': 0.2337601476829846, 'criterion': 'absolute_error'}. Best is trial 7 with value: 1.153445238095238.
# [I 2025-02-27 22:08:39,010] Trial 9 finished with value: 1.1886724440883094 and parameters: {'n_estimators': 300, 'max_depth': 16, 'min_samples_split': 11, 'min_samples_leaf': 3, 'max_features': 'log2', 'bootstrap': False, 'min_weight_fraction_leaf': 0.13003882708324788, 'criterion': 'squared_error'}. Best is trial 7 with value: 1.153445238095238.
# [I 2025-02-27 22:08:39,708] Trial 10 finished with value: 1.1195427083333334 and parameters: {'n_estimators': 400, 'max_depth': 35, 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.3588580389777818, 'max_samples': 0.678300167647249, 'criterion': 'absolute_error'}. Best is trial 10 with value: 1.1195427083333334.
# [I 2025-02-27 22:08:40,401] Trial 11 finished with value: 1.118904575892857 and parameters: {'n_estimators': 400, 'max_depth': 35, 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.37901461412314935, 'max_samples': 0.6679634895512288, 'criterion': 'absolute_error'}. Best is trial 11 with value: 1.118904575892857.
# [I 2025-02-27 22:08:41,068] Trial 12 finished with value: 1.1233177827380953 and parameters: {'n_estimators': 400, 'max_depth': 35, 'min_samples_split': 2, 'min_samples_leaf': 6, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.36379133830013793, 'max_samples': 0.601388129737501, 'criterion': 'absolute_error'}. Best is trial 11 with value: 1.118904575892857.
# [I 2025-02-27 22:08:41,794] Trial 13 finished with value: 1.1195427083333334 and parameters: {'n_estimators': 400, 'max_depth': 48, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.36385351837079155, 'max_samples': 0.6760813221858293, 'criterion': 'absolute_error'}. Best is trial 11 with value: 1.118904575892857.
# [I 2025-02-27 22:08:42,555] Trial 14 finished with value: 1.1170735491071428 and parameters: {'n_estimators': 400, 'max_depth': 33, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.35620562451469695, 'max_samples': 0.7325751873378029, 'criterion': 'absolute_error'}. Best is trial 14 with value: 1.1170735491071428.
# [I 2025-02-27 22:08:43,191] Trial 15 finished with value: 1.1222330903790088 and parameters: {'n_estimators': 350, 'max_depth': 30, 'min_samples_split': 5, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.3114134143823153, 'max_samples': 0.5241530869979899, 'criterion': 'absolute_error'}. Best is trial 14 with value: 1.1170735491071428.
# [I 2025-02-27 22:08:44,170] Trial 16 finished with value: 1.141112051734274 and parameters: {'n_estimators': 450, 'max_depth': 48, 'min_samples_split': 14, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.42812542242336565, 'max_samples': 0.9857957918769938, 'criterion': 'absolute_error'}. Best is trial 14 with value: 1.1170735491071428.
# [I 2025-02-27 22:08:45,047] Trial 17 finished with value: 1.1346895529640428 and parameters: {'n_estimators': 350, 'max_depth': 42, 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.2924869965679096, 'max_samples': 0.7726979671686158, 'criterion': 'absolute_error'}. Best is trial 14 with value: 1.1170735491071428.
# [I 2025-02-27 22:08:45,527] Trial 18 finished with value: 1.1293611992945327 and parameters: {'n_estimators': 450, 'max_depth': 29, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.4063805199505082, 'max_samples': 0.7078199132822506, 'criterion': 'absolute_error'}. Best is trial 14 with value: 1.1170735491071428.
# [I 2025-02-27 22:08:45,824] Trial 19 finished with value: 1.109116798941799 and parameters: {'n_estimators': 300, 'max_depth': 26, 'min_samples_split': 20, 'min_samples_leaf': 6, 'max_features': 'log2', 'bootstrap': True, 'min_weight_fraction_leaf': 0.2849316076315123, 'max_samples': 0.515179518585239, 'criterion': 'absolute_error'}. Best is trial 19 with value: 1.109116798941799.
# [I 2025-02-27 22:08:46,458] A new study created in memory with name: no-name-e4cd574c-2162-4ed5-9183-13b9af77c82c
# MSE (Home): 1.40, MSE (Away): 1.11
# Model Saved: eredivise
# Training model for seriea
# [I 2025-02-27 22:08:46,514] Trial 0 finished with value: 0.8178307692307693 and parameters: {'n_estimators': 50, 'max_depth': 38, 'min_samples_split': 18, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': False, 'min_weight_fraction_leaf': 0.33176444573412334, 'criterion': 'absolute_error'}. Best is trial 0 with value: 0.8178307692307693.
# [I 2025-02-27 22:08:46,600] Trial 1 finished with value: 0.7769846201076928 and parameters: {'n_estimators': 100, 'max_depth': 20, 'min_samples_split': 12, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True, 'min_weight_fraction_leaf': 0.36942111876098727, 'max_samples': 0.5152830263916837, 'criterion': 'squared_error'}. Best is trial 1 with value: 0.7769846201076928.
# [I 2025-02-27 22:08:49,236] Trial 2 finished with value: 0.9039206153846154 and parameters: {'n_estimators': 500, 'max_depth': 46, 'min_samples_split': 19, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': False, 'min_weight_fraction_leaf': 0.3189515948671798, 'criterion': 'absolute_error'}. Best is trial 1 with value: 0.7769846201076928.
# [I 2025-02-27 22:08:49,389] Trial 3 finished with value: 0.8020752136752137 and parameters: {'n_estimators': 150, 'max_depth': 49, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': False, 'min_weight_fraction_leaf': 0.3952293844090337, 'criterion': 'absolute_error'}. Best is trial 1 with value: 0.7769846201076928.
# [I 2025-02-27 22:08:51,864] Trial 4 finished with value: 1.25 and parameters: {'n_estimators': 450, 'max_depth': 49, 'min_samples_split': 16, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False, 'min_weight_fraction_leaf': 0.27462593897406795, 'criterion': 'absolute_error'}. Best is trial 1 with value: 0.7769846201076928.
# [I 2025-02-27 22:08:52,101] Trial 5 finished with value: 0.8131300105763357 and parameters: {'n_estimators': 300, 'max_depth': 26, 'min_samples_split': 20, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': False, 'min_weight_fraction_leaf': 0.46988699498467396, 'criterion': 'squared_error'}. Best is trial 1 with value: 0.7769846201076928.
# [I 2025-02-27 22:08:52,579] Trial 6 finished with value: 0.7414055021367522 and parameters: {'n_estimators': 300, 'max_depth': 24, 'min_samples_split': 15, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': False, 'min_weight_fraction_leaf': 0.08451753089601483, 'criterion': 'absolute_error'}. Best is trial 6 with value: 0.7414055021367522.
# ...
# [I 2025-02-27 22:09:36,098] Trial 19 finished with value: 1.2080717792250442 and parameters: {'n_estimators': 100, 'max_depth': 24, 'min_samples_split': 18, 'min_samples_leaf': 9, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.2525484180571699, 'max_samples': 0.6996529052885969, 'criterion': 'squared_error'}. Best is trial 12 with value: 1.183612842566713.
# [I 2025-02-27 22:09:36,500] A new study created in memory with name: no-name-e78d5d9d-e095-4eb3-bc16-bfa513e3aa20
# MSE (Home): 0.74, MSE (Away): 1.18
# Model Saved: laliga
# Training model for premier_league
# [I 2025-02-27 22:09:36,748] Trial 0 finished with value: 1.9953536577859554 and parameters: {'n_estimators': 450, 'max_depth': 11, 'min_samples_split': 8, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': False, 'min_weight_fraction_leaf': 0.42061986920166905, 'criterion': 'squared_error'}. Best is trial 0 with value: 1.9953536577859554.
# [I 2025-02-27 22:09:36,793] Trial 1 finished with value: 1.9577754298996046 and parameters: {'n_estimators': 50, 'max_depth': 12, 'min_samples_split': 16, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.3986752270415705, 'max_samples': 0.9064348568904212, 'criterion': 'squared_error'}. Best is trial 1 with value: 1.9577754298996046.
# [I 2025-02-27 22:09:36,886] Trial 2 finished with value: 2.2310679245283023 and parameters: {'n_estimators': 50, 'max_depth': 19, 'min_samples_split': 18, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.022330456716930236, 'max_samples': 0.8119513933136817, 'criterion': 'absolute_error'}. Best is trial 1 with value: 1.9577754298996046.
# [I 2025-02-27 22:09:36,959] Trial 3 finished with value: 2.011426434332809 and parameters: {'n_estimators': 100, 'max_depth': 34, 'min_samples_split': 15, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': False, 'min_weight_fraction_leaf': 0.05346182903451335, 'criterion': 'squared_error'}. Best is trial 1 with value: 1.9577754298996046.
# [I 2025-02-27 22:09:37,285] Trial 4 finished with value: 2.1334387924528304 and parameters: {'n_estimators': 250, 'max_depth': 14, 'min_samples_split': 18, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.03964439121815422, 'max_samples': 0.5919545075846167, 'criterion': 'absolute_error'}. Best is trial 1 with value: 1.9577754298996046.
# [I 2025-02-27 22:09:37,690] Trial 5 finished with value: 2.0774116673084326 and parameters: {'n_estimators': 350, 'max_depth': 49, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': 'log2', 'bootstrap': True, 'min_weight_fraction_leaf': 0.1869763409254877, 'max_samples': 0.9100990911829282, 'criterion': 'absolute_error'}. Best is trial 1 with value: 1.9577754298996046.
# [I 2025-02-27 22:09:38,075] Trial 6 finished with value: 2.0379941855987673 and parameters: {'n_estimators': 350, 'max_depth': 41, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': 'log2', 'bootstrap': False, 'min_weight_fraction_leaf': 0.24201249726779062, 'criterion': 'absolute_error'}. Best is trial 1 with value: 1.9577754298996046.
# [I 2025-02-27 22:09:38,486] Trial 7 finished with value: 2.0427235849056604 and parameters: {'n_estimators': 400, 'max_depth': 19, 'min_samples_split': 17, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'bootstrap': False, 'min_weight_fraction_leaf': 0.44675620096075613, 'criterion': 'absolute_error'}. Best is trial 1 with value: 1.9577754298996046.
# [I 2025-02-27 22:09:38,614] Trial 8 finished with value: 2.042808962264151 and parameters: {'n_estimators': 100, 'max_depth': 30, 'min_samples_split': 20, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': False, 'min_weight_fraction_leaf': 0.2618527827081483, 'criterion': 'absolute_error'}. Best is trial 1 with value: 1.9577754298996046.
# [I 2025-02-27 22:09:39,711] Trial 9 finished with value: 2.352722292103424 and parameters: {'n_estimators': 450, 'max_depth': 34, 'min_samples_split': 9, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': False, 'min_weight_fraction_leaf': 0.0072495702292829645, 'criterion': 'absolute_error'}. Best is trial 1 with value: 1.9577754298996046.
# [I 2025-02-27 22:09:40,013] Trial 10 finished with value: 1.9091166902897396 and parameters: {'n_estimators': 200, 'max_depth': 3, 'min_samples_split': 13, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.3492098263416093, 'max_samples': 0.9657732969007546, 'criterion': 'squared_error'}. Best is trial 10 with value: 1.9091166902897396.
# [I 2025-02-27 22:09:40,252] Trial 11 finished with value: 1.9027834231995993 and parameters: {'n_estimators': 200, 'max_depth': 3, 'min_samples_split': 13, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.34737316202890334, 'max_samples': 0.9597019796317143, 'criterion': 'squared_error'}. Best is trial 11 with value: 1.9027834231995993.
# [I 2025-02-27 22:09:40,483] Trial 12 finished with value: 1.911944530593131 and parameters: {'n_estimators': 200, 'max_depth': 3, 'min_samples_split': 13, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.34480557698242636, 'max_samples': 0.9911141862460651, 'criterion': 'squared_error'}. Best is trial 11 with value: 1.9027834231995993.
# [I 2025-02-27 22:09:40,723] Trial 13 finished with value: 1.9159463713997487 and parameters: {'n_estimators': 200, 'max_depth': 3, 'min_samples_split': 12, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.3215344526226789, 'max_samples': 0.9984469756145827, 'criterion': 'squared_error'}. Best is trial 11 with value: 1.9027834231995993.
# [I 2025-02-27 22:09:40,950] Trial 14 finished with value: 1.94615450594755 and parameters: {'n_estimators': 200, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.4928109168280177, 'max_samples': 0.7189491424408195, 'criterion': 'squared_error'}. Best is trial 11 with value: 1.9027834231995993.
# [I 2025-02-27 22:09:41,329] Trial 15 finished with value: 1.9170172247754158 and parameters: {'n_estimators': 300, 'max_depth': 23, 'min_samples_split': 14, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.17237174809869396, 'max_samples': 0.826453792266329, 'criterion': 'squared_error'}. Best is trial 11 with value: 1.9027834231995993.
# [I 2025-02-27 22:09:41,499] Trial 16 finished with value: 1.9046847302357646 and parameters: {'n_estimators': 150, 'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.343154181238359, 'max_samples': 0.6877131532659537, 'criterion': 'squared_error'}. Best is trial 11 with value: 1.9027834231995993.
# [I 2025-02-27 22:09:41,680] Trial 17 finished with value: 1.8908624843420565 and parameters: {'n_estimators': 150, 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.29203273624350884, 'max_samples': 0.6513019237107399, 'criterion': 'squared_error'}. Best is trial 17 with value: 1.8908624843420565.
# [I 2025-02-27 22:09:41,961] Trial 18 finished with value: 1.9074484092837436 and parameters: {'n_estimators': 250, 'max_depth': 19, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.2648094315488764, 'max_samples': 0.5409556154301496, 'criterion': 'squared_error'}. Best is trial 17 with value: 1.8908624843420565.
# [I 2025-02-27 22:09:42,159] Trial 19 finished with value: 1.965561495788576 and parameters: {'n_estimators': 150, 'max_depth': 14, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.17790801261721456, 'max_samples': 0.6211478483358672, 'criterion': 'squared_error'}. Best is trial 17 with value: 1.8908624843420565.
# [I 2025-02-27 22:09:42,160] A new study created in memory with name: no-name-fb6a5f77-d0de-4543-a397-df0c181d4f6e
# [I 2025-02-27 22:09:42,214] Trial 0 finished with value: 1.693335849056604 and parameters: {'n_estimators': 50, 'max_depth': 24, 'min_samples_split': 16, 'min_samples_leaf': 3, 'max_features': 'log2', 'bootstrap': False, 'min_weight_fraction_leaf': 0.4796966550327181, 'criterion': 'absolute_error'}. Best is trial 0 with value: 1.693335849056604.
# [I 2025-02-27 22:09:42,480] Trial 1 finished with value: 1.577253183962264 and parameters: {'n_estimators': 200, 'max_depth': 4, 'min_samples_split': 7, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.15476154422209581, 'max_samples': 0.8187294877388731, 'criterion': 'absolute_error'}. Best is trial 1 with value: 1.577253183962264.
# [I 2025-02-27 22:09:42,870] Trial 2 finished with value: 1.562379829521804 and parameters: {'n_estimators': 300, 'max_depth': 47, 'min_samples_split': 16, 'min_samples_leaf': 8, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.03313092801758505, 'max_samples': 0.5969832986391381, 'criterion': 'squared_error'}. Best is trial 2 with value: 1.562379829521804.
# [I 2025-02-27 22:09:43,145] Trial 3 finished with value: 1.7512409243492644 and parameters: {'n_estimators': 350, 'max_depth': 10, 'min_samples_split': 12, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': False, 'min_weight_fraction_leaf': 0.00026488133576685335, 'criterion': 'squared_error'}. Best is trial 2 with value: 1.562379829521804.
# [I 2025-02-27 22:09:43,240] Trial 4 finished with value: 1.6639849056603775 and parameters: {'n_estimators': 100, 'max_depth': 25, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': False, 'min_weight_fraction_leaf': 0.47383080600142086, 'criterion': 'absolute_error'}. Best is trial 2 with value: 1.562379829521804.
# [I 2025-02-27 22:09:45,511] Trial 5 finished with value: 1.9811320754716981 and parameters: {'n_estimators': 300, 'max_depth': 33, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': False, 'min_weight_fraction_leaf': 0.13835268031576414, 'criterion': 'absolute_error'}. Best is trial 2 with value: 1.562379829521804.
# [I 2025-02-27 22:09:46,665] Trial 6 finished with value: 1.9811320754716981 and parameters: {'n_estimators': 150, 'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 6, 'max_features': None, 'bootstrap': False, 'min_weight_fraction_leaf': 0.13628098973256625, 'criterion': 'absolute_error'}. Best is trial 2 with value: 1.562379829521804.
# [I 2025-02-27 22:09:46,950] Trial 7 finished with value: 1.695285157375395 and parameters: {'n_estimators': 500, 'max_depth': 36, 'min_samples_split': 12, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': False, 'min_weight_fraction_leaf': 0.24358866552287312, 'criterion': 'squared_error'}. Best is trial 2 with value: 1.562379829521804.
# [I 2025-02-27 22:09:47,213] Trial 8 finished with value: 1.6651407547169808 and parameters: {'n_estimators': 250, 'max_depth': 21, 'min_samples_split': 6, 'min_samples_leaf': 6, 'max_features': 'log2', 'bootstrap': True, 'min_weight_fraction_leaf': 0.3082574377535733, 'max_samples': 0.9892066538362008, 'criterion': 'absolute_error'}. Best is trial 2 with value: 1.562379829521804.
# [I 2025-02-27 22:09:47,481] Trial 9 finished with value: 1.580100095737804 and parameters: {'n_estimators': 450, 'max_depth': 16, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'log2', 'bootstrap': False, 'min_weight_fraction_leaf': 0.11280168977531613, 'criterion': 'squared_error'}. Best is trial 2 with value: 1.562379829521804.
# [I 2025-02-27 22:09:47,954] Trial 10 finished with value: 1.563511735722251 and parameters: {'n_estimators': 400, 'max_depth': 50, 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.01818616668374534, 'max_samples': 0.5019209559560766, 'criterion': 'squared_error'}. Best is trial 2 with value: 1.562379829521804.
# [I 2025-02-27 22:09:48,429] Trial 11 finished with value: 1.584279998626289 and parameters: {'n_estimators': 400, 'max_depth': 48, 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.004526552478822221, 'max_samples': 0.5279981099683118, 'criterion': 'squared_error'}. Best is trial 2 with value: 1.562379829521804.
# [I 2025-02-27 22:09:48,867] Trial 12 finished with value: 1.5737909662187541 and parameters: {'n_estimators': 350, 'max_depth': 49, 'min_samples_split': 19, 'min_samples_leaf': 10, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.060389320429785884, 'max_samples': 0.5026047732613732, 'criterion': 'squared_error'}. Best is trial 2 with value: 1.562379829521804.
# [I 2025-02-27 22:09:49,216] Trial 13 finished with value: 1.6595346476756145 and parameters: {'n_estimators': 300, 'max_depth': 42, 'min_samples_split': 16, 'min_samples_leaf': 8, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.24586611906654793, 'max_samples': 0.6630064066357464, 'criterion': 'squared_error'}. Best is trial 2 with value: 1.562379829521804.
# [I 2025-02-27 22:09:49,778] Trial 14 finished with value: 1.5586151356677023 and parameters: {'n_estimators': 400, 'max_depth': 41, 'min_samples_split': 16, 'min_samples_leaf': 8, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.06415163414909412, 'max_samples': 0.633227338333392, 'criterion': 'squared_error'}. Best is trial 14 with value: 1.5586151356677023.
# [I 2025-02-27 22:09:50,284] Trial 15 finished with value: 1.7631512498322404 and parameters: {'n_estimators': 500, 'max_depth': 40, 'min_samples_split': 15, 'min_samples_leaf': 8, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.3459688681637653, 'max_samples': 0.6791208071460936, 'criterion': 'squared_error'}. Best is trial 14 with value: 1.5586151356677023.
# [I 2025-02-27 22:09:50,650] Trial 16 finished with value: 1.5728208234309873 and parameters: {'n_estimators': 250, 'max_depth': 31, 'min_samples_split': 14, 'min_samples_leaf': 8, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.07246428000692134, 'max_samples': 0.6430062869647799, 'criterion': 'squared_error'}. Best is trial 14 with value: 1.5586151356677023.
# [I 2025-02-27 22:09:51,138] Trial 17 finished with value: 1.6029809212033412 and parameters: {'n_estimators': 400, 'max_depth': 43, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.1942466679584175, 'max_samples': 0.7799136756936215, 'criterion': 'squared_error'}. Best is trial 14 with value: 1.5586151356677023.
# [I 2025-02-27 22:09:51,420] Trial 18 finished with value: 1.5705153557891485 and parameters: {'n_estimators': 200, 'max_depth': 38, 'min_samples_split': 18, 'min_samples_leaf': 9, 'max_features': None, 'bootstrap': True, 'min_weight_fraction_leaf': 0.07219350379932216, 'max_samples': 0.5942971937700057, 'criterion': 'squared_error'}. Best is trial 14 with value: 1.5586151356677023.
# [I 2025-02-27 22:09:51,739] Trial 19 finished with value: 1.7569307933594636 and parameters: {'n_estimators': 350, 'max_depth': 45, 'min_samples_split': 17, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'bootstrap': True, 'min_weight_fraction_leaf': 0.3850802222571088, 'max_samples': 0.7289715098256009, 'criterion': 'squared_error'}. Best is trial 14 with value: 1.5586151356677023.
# MSE (Home): 1.89, MSE (Away): 1.56
# Model Saved: premier_league
# Training Completed
